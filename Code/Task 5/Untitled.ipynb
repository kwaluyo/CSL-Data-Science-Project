# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import autokeras as ak

# %%
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv("..\..\Rdata\exp_blood.csv")
X = X.T
X = X.iloc[:,1:21]
X.head()
# Out:
#                   1         2         3         4         5         6   \
# GTEX-111YS  1.930523 -0.757455 -2.041961  3.202670  0.343052  2.644519
# GTEX-1122O  1.275000 -2.178112 -0.375721  3.300398  1.148202  1.781592
# GTEX-1128S  3.502239  0.886703 -0.072575  2.585954  2.748351  3.438855
# GTEX-117YW  3.509703 -0.361041  1.206757  4.961396  2.666126  3.895245
# GTEX-11DXX  1.826457 -2.001952 -3.559578  2.441123  0.464729  1.706664
#
#                   7         8         9         10        11        12  \
# GTEX-111YS  0.343052 -0.526786  6.687479  3.754207  0.060469  5.555536
# GTEX-1122O -0.580108  0.236274  6.318191  3.300398 -0.982725  5.519512
# GTEX-1128S  4.121367  2.833991  6.295443  0.655331  1.251968  4.642054
# GTEX-117YW  4.129973  4.595527  6.644001  1.608370 -0.275084  4.199183
# GTEX-11DXX  1.381092  0.336065  6.296894  3.648778 -0.570120  5.353086
#
#                   13        14        15        16        17        18  \
# GTEX-111YS  0.897850  5.154865  2.895801  5.786457  4.676676  0.221416
# GTEX-1122O  0.508208  4.892593  2.239037  5.282730  4.677574  0.664641
# GTEX-1128S  2.169060  5.840005  1.528039  6.322035  3.714498  1.332648
# GTEX-117YW  3.280523  5.843502  2.627590  6.735179  3.878933  0.980820
# GTEX-11DXX -0.426218  4.372572  2.120136  5.097282  4.761292  0.414632
#
#                   19        20
# GTEX-111YS  3.941128 -0.915929
# GTEX-1122O  3.361692  0.285307
# GTEX-1128S  4.656057  0.508705
# GTEX-117YW  5.190165  1.585574
# GTEX-11DXX  3.654186 -0.621465

# %%
Y = pd.read_csv("..\..\Rdata\exp_other.csv")
Y = Y.T
Y = Y.iloc[:,1:21]
Y.head()
# Out:
#                   1         2         3         4         5         6   \
# GTEX-111YS  3.605865 -0.267521  3.184108  3.877916  6.992831  3.997613
# GTEX-1122O  3.966150  0.517386  3.422275  4.272583  7.030410  4.070818
# GTEX-1128S  4.392573  1.411392  3.491767  4.466593  6.707747  4.035884
# GTEX-117YW  4.029355  1.747977  5.045113  5.187642  7.266217  4.812552
# GTEX-11DXX  4.006143  0.232579  2.753910  3.901730  7.207189  4.116435
#
#                   7         8         9         10        11        12  \
# GTEX-111YS  0.117833  1.184032  7.020417  4.108135 -0.358687  5.391834
# GTEX-1122O  0.616944  2.067803  7.161402  4.611213 -0.589915  5.524136
# GTEX-1128S  2.649249  2.521119  7.290918  2.921555  0.001869  5.329000
# GTEX-117YW  3.737062  3.623192  7.396777  2.876740  1.268339  5.531536
# GTEX-11DXX  0.232579  2.549841  7.286009  4.922356 -0.055634  5.547327
#
#                   13        14        15        16        17        18  \
# GTEX-111YS  2.072186  5.907981  3.033895  6.189503  4.374242 -0.390403
# GTEX-1122O  2.664486  6.201210  3.183342  6.528943  4.994211  0.500104
# GTEX-1128S  2.347286  5.916391  2.824356  6.831217  4.168531  0.030042
# GTEX-117YW  4.279979  7.058385  2.771582  6.944706  4.025701  0.394224
# GTEX-11DXX  2.207209  6.367139  3.139964  6.558992  4.587195  0.588563
#
#                   19        20
# GTEX-111YS  6.272859  6.140755
# GTEX-1122O  6.440264  6.538761
# GTEX-1128S  6.371695  6.634517
# GTEX-117YW  6.410789  8.492405
# GTEX-11DXX  6.324252  7.194481

# %%
print(X.shape)
print(Y.shape)
# Out:
# (467, 20)
# (467, 20)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

# %%
# It tries 10 different models.
reg = ak.StructuredDataRegressor(max_trials=3, overwrite=True)

# %%
# Feed the structured data regressor with training data.
reg.fit(X_train, Y_train, epochs=10)
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# structured_data...|True              |?
# structured_data...|2                 |?
# structured_data...|False             |?
# structured_data...|0                 |?
# structured_data...|32                |?
# structured_data...|32                |?
# regression_head...|0                 |?
# optimizer         |adam              |?
# learning_rate     |0.001             |?
#
# Epoch 1/10
#  1/10 [==>...........................] - ETA: 35s - loss: 23.2674 - mean_squared_error: 23.2674WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0022s vs `on_train_batch_end` time: 0.0036s). Check your callbacks.
# 10/10 [==============================] - 5s 80ms/step - loss: 22.6956 - mean_squared_error: 22.6956 - val_loss: 21.6809 - val_mean_squared_error: 21.6809
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-8-91985969f386> in <module>
#       1 # Feed the structured data regressor with training data.
# ----> 2 reg.fit(X_train, Y_train, epochs=10)
#
# ~\Anaconda3\envs\CV\lib\site-packages\autokeras\tasks\structured_data.py in fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     139             validation_split=validation_split,
#     140             validation_data=validation_data,
# --> 141             **kwargs
#     142         )
#     143
#
# ~\Anaconda3\envs\CV\lib\site-packages\autokeras\auto_model.py in fit(self, x, y, batch_size, epochs, callbacks, validation_split, validation_data, verbose, **kwargs)
#     283             validation_split=validation_split,
#     284             verbose=verbose,
# --> 285             **kwargs
#     286         )
#     287
#
# ~\Anaconda3\envs\CV\lib\site-packages\autokeras\engine\tuner.py in search(self, epochs, callbacks, validation_split, verbose, **fit_kwargs)
#     187
#     188         super().search(
# --> 189             epochs=epochs, callbacks=new_callbacks, verbose=verbose, **fit_kwargs
#     190         )
#     191
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras_tuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     142
#     143             self.on_trial_begin(trial)
# --> 144             self.run_trial(trial, *fit_args, **fit_kwargs)
#     145             self.on_trial_end(trial)
#     146         self.on_search_end()
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras_tuner\engine\tuner.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     181         copied_fit_kwargs["callbacks"] = callbacks
#     182
# --> 183         self._build_and_fit_model(trial, fit_args, copied_fit_kwargs)
#     184
#     185     def save_model(self, trial_id, model, step=0):
#
# ~\Anaconda3\envs\CV\lib\site-packages\autokeras\engine\tuner.py in _build_and_fit_model(self, trial, fit_args, fit_kwargs)
#     100
#     101         _, history = utils.fit_with_adaptive_batch_size(
# --> 102             model, self.hypermodel.hypermodel.batch_size, **fit_kwargs
#     103         )
#     104         return history
#
# ~\Anaconda3\envs\CV\lib\site-packages\autokeras\utils\utils.py in fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs)
#      86 def fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs):
#      87     history = run_with_adaptive_batch_size(
# ---> 88         batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#      89     )
#      90     return model, history
#
# ~\Anaconda3\envs\CV\lib\site-packages\autokeras\utils\utils.py in run_with_adaptive_batch_size(batch_size, func, **fit_kwargs)
#      98     while batch_size > 0:
#      99         try:
# --> 100             history = func(x=x, validation_data=validation_data, **fit_kwargs)
#     101             break
#     102         except tf.errors.ResourceExhaustedError as e:
#
# ~\Anaconda3\envs\CV\lib\site-packages\autokeras\utils\utils.py in <lambda>(**kwargs)
#      86 def fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs):
#      87     history = run_with_adaptive_batch_size(
# ---> 88         batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#      89     )
#      90     return model, history
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1228           epoch_logs.update(val_logs)
#    1229
# -> 1230         callbacks.on_epoch_end(epoch, epoch_logs)
#    1231         training_logs = epoch_logs
#    1232         if self.stop_training:
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     411     logs = self._process_logs(logs)
#     412     for callback in self.callbacks:
# --> 413       callback.on_epoch_end(epoch, logs)
#     414
#     415   def on_train_batch_begin(self, batch, logs=None):
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras_tuner\engine\tuner_utils.py in on_epoch_end(self, epoch, logs)
#      90
#      91     def on_epoch_end(self, epoch, logs=None):
# ---> 92         self.tuner.on_epoch_end(self.trial, self.model, epoch, logs=logs)
#      93
#      94
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras_tuner\engine\tuner.py in on_epoch_end(self, trial, model, epoch, logs)
#     255               the value of the objective for this epoch.
#     256         """
# --> 257         self.save_model(trial.trial_id, model, step=epoch)
#     258         # Report intermediate metrics to the `Oracle`.
#     259         status = self.oracle.update_trial(trial.trial_id, metrics=logs, step=epoch)
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras_tuner\engine\tuner.py in save_model(self, trial_id, model, step)
#     185     def save_model(self, trial_id, model, step=0):
#     186         epoch = step
# --> 187         self._checkpoint_model(model, trial_id, epoch)
#     188         # TODO: save the top epoch checkpoints instead of last ones.
#     189         epoch_to_delete = epoch - self._save_n_checkpoints
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras_tuner\engine\tuner.py in _checkpoint_model(self, model, trial_id, epoch)
#     338         fname = self._get_checkpoint_fname(trial_id, epoch)
#     339         # Save in TF format.
# --> 340         model.save_weights(fname)
#     341         return fname
#     342
#
# ~\Anaconda3\envs\CV\lib\site-packages\keras\engine\training.py in save_weights(self, filepath, overwrite, save_format, options)
#    2256       else:
#    2257         session = backend.get_session()
# -> 2258       self._trackable_saver.save(filepath, session=session, options=options)
#    2259       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    2260       tf.__internal__.train.update_checkpoint_state(
#
# ~\Anaconda3\envs\CV\lib\site-packages\tensorflow\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session, options)
#    1261     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1262     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1263         file_prefix_tensor, object_graph_tensor, options)
#    1264     if new_feed_additions:
#    1265       feed_dict.update(new_feed_additions)
#
# ~\Anaconda3\envs\CV\lib\site-packages\tensorflow\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor, options)
#    1206         or context.executing_eagerly() or ops.inside_function()):
#    1207       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1208       save_op = saver.save(file_prefix, options=options)
#    1209       with ops.device("/cpu:0"):
#    1210         with ops.control_dependencies([save_op]):
#
# ~\Anaconda3\envs\CV\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save(self, file_prefix, options)
#     298       tf_function_save()
#     299     else:
# --> 300       return save_fn()
#     301
#     302   def restore(self, file_prefix, options=None):
#
# ~\Anaconda3\envs\CV\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save_fn()
#     272           # initial read operations should be placed on the SaveableObject's
#     273           # device.
# --> 274           sharded_saves.append(saver.save(shard_prefix, options))
#     275
#     276       with ops.control_dependencies(sharded_saves):
#
# ~\Anaconda3\envs\CV\lib\site-packages\tensorflow\python\training\saving\functional_saver.py in save(self, file_prefix, options)
#      81     save_device = options.experimental_io_device or "cpu:0"
#      82     with ops.device(save_device):
# ---> 83       return io_ops.save_v2(file_prefix, tensor_names, tensor_slices, tensors)
#      84
#      85   def restore(self, file_prefix, options=None):
#
# ~\Anaconda3\envs\CV\lib\site-packages\tensorflow\python\ops\gen_io_ops.py in save_v2(prefix, tensor_names, shape_and_slices, tensors, name)
#    1695       return save_v2_eager_fallback(
#    1696           prefix, tensor_names, shape_and_slices, tensors, name=name,
# -> 1697           ctx=_ctx)
#    1698     except _core._SymbolicException:
#    1699       pass  # Add nodes to the TensorFlow graph.
#
# ~\Anaconda3\envs\CV\lib\site-packages\tensorflow\python\ops\gen_io_ops.py in save_v2_eager_fallback(prefix, tensor_names, shape_and_slices, tensors, name, ctx)
#    1715   _attrs = ("dtypes", _attr_dtypes)
#    1716   _result = _execute.execute(b"SaveV2", 0, inputs=_inputs_flat, attrs=_attrs,
# -> 1717                              ctx=ctx, name=name)
#    1718   _result = None
#    1719   return _result
#
# ~\Anaconda3\envs\CV\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# NotFoundError: Failed to create a NewWriteableFile: .\structured_data_regressor\trial_baf872524973be76386365979daecfbe\checkpoints\epoch_0\checkpoint_temp/part-00000-of-00001.data-00000-of-00001.tempstate4060611682520540933 : The system cannot find the path specified.
# ; No such process [Op:SaveV2]

# %%
# Predict with the best model.
predicted_y = reg.predict(x_test)

# %%
# Evaluate the best model with testing data.
print(reg.evaluate(x_test, Y_test))

# %%
from sklearn.datasets import fetch_california_housing

house_dataset = fetch_california_housing()
df = pd.DataFrame(
    np.concatenate(
        (house_dataset.data, house_dataset.target.reshape(-1, 1)), axis=1
    ),
    columns=house_dataset.feature_names + ["Price"],
)
train_size = int(df.shape[0] * 0.9)
df[:train_size].to_csv("train.csv", index=False)
df[train_size:].to_csv("eval.csv", index=False)
train_file_path = "train.csv"
test_file_path = "eval.csv"

# %%
# Initialize the structured data regressor.
reg = ak.StructuredDataRegressor(
    overwrite=True, max_trials=3
)  # It tries 3 different models.
# Feed the structured data regressor with training data.
reg.fit(
    # The path to the train.csv file.
    train_file_path,
    # The name of the label column.
    "Price",
    epochs=10,
)

# %%
# Predict with the best model.
predicted_y = reg.predict(test_file_path)
# Evaluate the best model with testing data.
print(reg.evaluate(test_file_path, "Price"))

# %%
import os
from sklearn.datasets import load_files

# %%
dataset = tf.keras.utils.get_file(
    fname="aclImdb.tar.gz",
    origin="http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz",
    extract=True,
)

# set path to dataset
IMDB_DATADIR = os.path.join(os.path.dirname(dataset), "aclImdb")

classes = ["pos", "neg"]
train_data = load_files(
    os.path.join(IMDB_DATADIR, "train"), shuffle=True, categories=classes
)
test_data = load_files(
    os.path.join(IMDB_DATADIR, "test"), shuffle=False, categories=classes
)

x_train = np.array(train_data.data)
y_train = np.array(train_data.target)
x_test = np.array(test_data.data)
y_test = np.array(test_data.target)

print(x_train.shape)  # (25000,)
print(y_train.shape)  # (25000, 1)
print(x_train[0][:50])  # <START> this film was just brilliant casting <UNK>

# %%
# Initialize the text regressor.
reg = ak.TextRegressor(overwrite=True, max_trials=1)  # It tries 10 different models.
# Feed the text regressor with training data.
reg.fit(x_train, y_train, epochs=2)
# Predict with the best model.
predicted_y = reg.predict(x_test)
# Evaluate the best model with testing data.
print(reg.evaluate(x_test, y_test))

# %%
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train[:100]
y_train = y_train[:100]
print(x_train.shape)  # (60000, 28, 28)
print(y_train.shape)  # (60000,)
print(y_train[:3])  # array([7, 2, 1], dtype=uint8)

# %%
# Initialize the image regressor.
reg = ak.ImageRegressor(overwrite=True, max_trials=1)
# Feed the image regressor with training data.
reg.fit(x_train, y_train, epochs=2)


# Predict with the best model.
predicted_y = reg.predict(x_test)
print(predicted_y)


# Evaluate the best model with testing data.
print(reg.evaluate(x_test, y_test))
